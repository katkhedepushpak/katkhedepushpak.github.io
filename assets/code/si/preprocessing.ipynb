# %%
import pandas as pd

# Read evap.xlsx
evap_df = pd.read_excel('evap.xlsx')

# Read GWS_tavg.xlsx
GWS_tavg_df = pd.read_excel('GWS_tavg.xlsx')

# Read Rain_f_ta.xlsx
Rain_f_ta_df = pd.read_excel('Rain_f_ta.xlsx')

# Read SWE_tavg.xlsx
SWE_tavg_df = pd.read_excel('SWE_tavg.xlsx')

# Read Tair_f_tavg.xlsx
Tair_f_tavg_df = pd.read_excel('Tair_f_tavg.xlsx')

# Read TWS_tavg.xlsx
TWS_tavg_df = pd.read_excel('TWS_tavg.xlsx')

# Read WS2_Discharge.csv
WS2_Discharge_df = pd.read_csv('WS2_Discharge.csv')

# Read WS2_DSi.csv
WS2_DSi_df = pd.read_csv('WS2_DSi.csv')

# Displaying the first few rows of each dataframe
print("evap_df:")
print(evap_df.head())

print("\nGWS_tavg_df:")
print(GWS_tavg_df.head())

print("\nRain_f_ta_df:")
print(Rain_f_ta_df.head())

print("\nSWE_tavg_df:")
print(SWE_tavg_df.head())

print("\nTair_f_tavg_df:")
print(Tair_f_tavg_df.head())

print("\nTWS_tavg_df:")
print(TWS_tavg_df.head())

print("\nWS2_Discharge_df:")
print(WS2_Discharge_df.head())

print("\nWS2_DSi_df:")
print(WS2_DSi_df.head())
# Out:
# C:\Users\katkh\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell A2 is marked as a date but the serial value 19650101 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
# evap_df:
#          Date   HBR_ws2
# 0         NaN  0.000134
# 1  19650102.0  0.000074
# 2  19650103.0  0.000081
# 3  19650104.0  0.000080
# 4  19650105.0  0.000034
#
# GWS_tavg_df:
#        Date      HBR_ws2
# 0  19650101  1355.841064
# 1  19650102  1355.867798
# 2  19650103  1355.743408
# 3  19650104  1355.505737
# 4  19650105  1355.300537
#
# Rain_f_ta_df:
#        Date       HBR_ws2
# 0  19650101  4.758085e-07
# 1  19650102  1.472223e-06
# 2  19650103  2.042398e-05
# 3  19650104  9.216375e-05
# 4  19650105  2.777230e-05
#
# SWE_tavg_df:
#        Date    HBR_ws2
# 0  19650101  32.474033
# 1  19650102  22.969460
# 2  19650103  18.499897
# 3  19650104  17.172014
# 4  19650105  16.777233
#
# Tair_f_tavg_df:
# ...

# %%
# Convert 'Date' column to datetime format
evap_df['Date'] = pd.to_datetime(evap_df['Date'], format='%Y%m%d')
GWS_tavg_df['Date'] = pd.to_datetime(GWS_tavg_df['Date'], format='%Y%m%d')
Rain_f_ta_df['Date'] = pd.to_datetime(Rain_f_ta_df['Date'], format='%Y%m%d')
SWE_tavg_df['Date'] = pd.to_datetime(SWE_tavg_df['Date'], format='%Y%m%d')
Tair_f_tavg_df['Date'] = pd.to_datetime(Tair_f_tavg_df['Date'], format='%Y%m%d')
TWS_tavg_df['Date'] = pd.to_datetime(TWS_tavg_df['Date'], format='%Y%m%d')

# Displaying the first few rows of each dataframe
print("evap_df:")
print(evap_df.head())

print("\nGWS_tavg_df:")
print(GWS_tavg_df.head())

print("\nRain_f_ta_df:")
print(Rain_f_ta_df.head())

print("\nSWE_tavg_df:")
print(SWE_tavg_df.head())

print("\nTair_f_tavg_df:")
print(Tair_f_tavg_df.head())

print("\nTWS_tavg_df:")
print(TWS_tavg_df.head())

print("\nWS2_Discharge_df:")
print(WS2_Discharge_df.head())

print("\nWS2_DSi_df:")
print(WS2_DSi_df.head())



evap_df.iloc[0, 0] = '1965-01-01'

# Convert 'Date' column to datetime format
evap_df['Date'] = pd.to_datetime(evap_df['Date'], format='%Y%m%d')
print(evap_df.head())
# Out:
# evap_df:
#         Date   HBR_ws2
# 0        NaT  0.000134
# 1 1965-01-02  0.000074
# 2 1965-01-03  0.000081
# 3 1965-01-04  0.000080
# 4 1965-01-05  0.000034
#
# GWS_tavg_df:
#         Date      HBR_ws2
# 0 1965-01-01  1355.841064
# 1 1965-01-02  1355.867798
# 2 1965-01-03  1355.743408
# 3 1965-01-04  1355.505737
# 4 1965-01-05  1355.300537
#
# Rain_f_ta_df:
#         Date       HBR_ws2
# 0 1965-01-01  4.758085e-07
# 1 1965-01-02  1.472223e-06
# 2 1965-01-03  2.042398e-05
# 3 1965-01-04  9.216375e-05
# 4 1965-01-05  2.777230e-05
#
# SWE_tavg_df:
#         Date    HBR_ws2
# 0 1965-01-01  32.474033
# 1 1965-01-02  22.969460
# 2 1965-01-03  18.499897
# 3 1965-01-04  17.172014
# 4 1965-01-05  16.777233
#
# Tair_f_tavg_df:
#         Date     HBR_ws2
# 0 1965-01-01  264.929535
# 1 1965-01-02  260.363312
# 2 1965-01-03  263.606293
# 3 1965-01-04  266.839752
# 4 1965-01-05  263.835114
#
# TWS_tavg_df:
#         Date      HBR_ws2
# 0 1965-01-01  1599.702271
# 1 1965-01-02  1590.059570
# ...

# %%
print("Shape:", evap_df.shape)
print("Shape:", GWS_tavg_df.shape)
print("Shape:", Rain_f_ta_df.shape)
print("Shape:", GWS_tavg_df.shape)
print("Shape:", SWE_tavg_df.shape)
print("Shape:", Tair_f_tavg_df.shape)
print("Shape:", TWS_tavg_df.shape)
print("Shape:", WS2_Discharge_df.shape)
print("Shape:", WS2_DSi_df.shape)
# Out:
# Shape: (4816, 2)
# Shape: (4816, 2)
# Shape: (4816, 2)
# Shape: (4816, 2)
# Shape: (4816, 2)
# Shape: (4816, 2)
# Shape: (4816, 2)
# Shape: (4748, 3)
# Shape: (134, 3)

# %%
WS2_DSi_df.drop(columns=['Unnamed: 0'], inplace=True)
WS2_Discharge_df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
print("Shape:", evap_df.shape)
print("Shape:", GWS_tavg_df.shape)
print("Shape:", Rain_f_ta_df.shape)
print("Shape:", GWS_tavg_df.shape)
print("Shape:", SWE_tavg_df.shape)
print("Shape:", Tair_f_tavg_df.shape)
print("Shape:", TWS_tavg_df.shape)
print("Shape:", WS2_Discharge_df.shape)
print("Shape:", WS2_DSi_df.shape)
# Out:
# Shape: (4816, 2)
# Shape: (4816, 2)
# Shape: (4816, 2)
# Shape: (4816, 2)
# Shape: (4816, 2)
# Shape: (4816, 2)
# Shape: (4816, 2)
# Shape: (4748, 2)
# Shape: (134, 2)

# %%
# Displaying the first few rows of each dataframe
print("evap_df:")
print(evap_df.head())

print("\nGWS_tavg_df:")
print(GWS_tavg_df.head())

print("\nRain_f_ta_df:")
print(Rain_f_ta_df.head())

print("\nSWE_tavg_df:")
print(SWE_tavg_df.head())

print("\nTair_f_tavg_df:")
print(Tair_f_tavg_df.head())

print("\nTWS_tavg_df:")
print(TWS_tavg_df.head())

print("\nWS2_Discharge_df:")
print(WS2_Discharge_df.head())

print("\nWS2_DSi_df:")
print(WS2_DSi_df.head())
# Out:
# evap_df:
#         Date   HBR_ws2
# 0 1965-01-01  0.000134
# 1 1965-01-02  0.000074
# 2 1965-01-03  0.000081
# 3 1965-01-04  0.000080
# 4 1965-01-05  0.000034
#
# GWS_tavg_df:
#         Date      HBR_ws2
# 0 1965-01-01  1355.841064
# 1 1965-01-02  1355.867798
# 2 1965-01-03  1355.743408
# 3 1965-01-04  1355.505737
# 4 1965-01-05  1355.300537
#
# Rain_f_ta_df:
#         Date       HBR_ws2
# 0 1965-01-01  4.758085e-07
# 1 1965-01-02  1.472223e-06
# 2 1965-01-03  2.042398e-05
# 3 1965-01-04  9.216375e-05
# 4 1965-01-05  2.777230e-05
#
# SWE_tavg_df:
#         Date    HBR_ws2
# 0 1965-01-01  32.474033
# 1 1965-01-02  22.969460
# 2 1965-01-03  18.499897
# 3 1965-01-04  17.172014
# 4 1965-01-05  16.777233
#
# Tair_f_tavg_df:
#         Date     HBR_ws2
# 0 1965-01-01  264.929535
# 1 1965-01-02  260.363312
# 2 1965-01-03  263.606293
# 3 1965-01-04  266.839752
# 4 1965-01-05  263.835114
#
# TWS_tavg_df:
#         Date      HBR_ws2
# 0 1965-01-01  1599.702271
# 1 1965-01-02  1590.059570
# ...

# %%
# Displaying the first few rows of each dataframe
print("evap_df:")
print(evap_df.head())

print("\nGWS_tavg_df:")
print(GWS_tavg_df.head())

print("\nRain_f_ta_df:")
print(Rain_f_ta_df.head())

print("\nSWE_tavg_df:")
print(SWE_tavg_df.head())

print("\nTair_f_tavg_df:")
print(Tair_f_tavg_df.head())

print("\nTWS_tavg_df:")
print(TWS_tavg_df.head())

print("\nWS2_Discharge_df:")
print(WS2_Discharge_df.head())

print("\nWS2_DSi_df:")
print(WS2_DSi_df.head())
# Out:
# evap_df:
#         Date   HBR_ws2
# 0 1965-01-01  0.000134
# 1 1965-01-02  0.000074
# 2 1965-01-03  0.000081
# 3 1965-01-04  0.000080
# 4 1965-01-05  0.000034
#
# GWS_tavg_df:
#         Date      HBR_ws2
# 0 1965-01-01  1355.841064
# 1 1965-01-02  1355.867798
# 2 1965-01-03  1355.743408
# 3 1965-01-04  1355.505737
# 4 1965-01-05  1355.300537
#
# Rain_f_ta_df:
#         Date       HBR_ws2
# 0 1965-01-01  4.758085e-07
# 1 1965-01-02  1.472223e-06
# 2 1965-01-03  2.042398e-05
# 3 1965-01-04  9.216375e-05
# 4 1965-01-05  2.777230e-05
#
# SWE_tavg_df:
#         Date    HBR_ws2
# 0 1965-01-01  32.474033
# 1 1965-01-02  22.969460
# 2 1965-01-03  18.499897
# 3 1965-01-04  17.172014
# 4 1965-01-05  16.777233
#
# Tair_f_tavg_df:
#         Date     HBR_ws2
# 0 1965-01-01  264.929535
# 1 1965-01-02  260.363312
# 2 1965-01-03  263.606293
# 3 1965-01-04  266.839752
# 4 1965-01-05  263.835114
#
# TWS_tavg_df:
#         Date      HBR_ws2
# 0 1965-01-01  1599.702271
# 1 1965-01-02  1590.059570
# ...

# %%
# Convert 'Date' column to '1965-01-01' format
WS2_Discharge_df['Date'] = pd.to_datetime(WS2_Discharge_df['Date'], format='%m/%d/%Y').dt.strftime('%Y-%m-%d')

# Convert 'Date' column to '1965-01-01' format
WS2_DSi_df['Date'] = pd.to_datetime(WS2_DSi_df['Date'], format='%m/%d/%Y').dt.strftime('%Y-%m-%d')

print("WS2_Discharge_df:")
print(WS2_Discharge_df.head())


print("\nWS2_DSi_df:")
print(WS2_DSi_df.head())
# Out:
# WS2_Discharge_df:
#          Date         Q
# 0  1965-01-01  0.003768
# 1  1965-01-02  0.003078
# 2  1965-01-03  0.002452
# 3  1965-01-04  0.002017
# 4  1965-01-05  0.001921
#
# WS2_DSi_df:
#          Date  value_mgL
# 0  1965-01-15   1.967927
# 1  1965-02-15   1.953904
# 2  1965-03-15   1.939881
# 3  1965-04-15   1.771602
# 4  1965-05-15   1.953904

# %%
import matplotlib.pyplot as plt

# Plotting data
plt.figure(figsize=(15, 10))

# evap_df
plt.subplot(3, 2, 1)
plt.plot(evap_df['Date'], evap_df['HBR_ws2'])
plt.title('evap_df')
plt.xlabel('Date')
plt.ylabel('HBR_ws2')

# GWS_tavg_df
plt.subplot(3, 2, 2)
plt.plot(GWS_tavg_df['Date'], GWS_tavg_df['HBR_ws2'])
plt.title('GWS_tavg_df')
plt.xlabel('Date')
plt.ylabel('HBR_ws2')

# Rain_f_ta_df
plt.subplot(3, 2, 3)
plt.plot(Rain_f_ta_df['Date'], Rain_f_ta_df['HBR_ws2'])
plt.title('Rain_f_ta_df')
plt.xlabel('Date')
plt.ylabel('HBR_ws2')

# SWE_tavg_df
plt.subplot(3, 2, 4)
plt.plot(SWE_tavg_df['Date'], SWE_tavg_df['HBR_ws2'])
plt.title('SWE_tavg_df')
plt.xlabel('Date')
plt.ylabel('HBR_ws2')

# Tair_f_tavg_df
plt.subplot(3, 2, 5)
plt.plot(Tair_f_tavg_df['Date'], Tair_f_tavg_df['HBR_ws2'])
plt.title('Tair_f_tavg_df')
plt.xlabel('Date')
plt.ylabel('HBR_ws2')

# TWS_tavg_df
plt.subplot(3, 2, 6)
plt.plot(TWS_tavg_df['Date'], TWS_tavg_df['HBR_ws2'])
plt.title('TWS_tavg_df')
plt.xlabel('Date')
plt.ylabel('HBR_ws2')

plt.tight_layout()
plt.show()


# Plotting WS2_Discharge_df
plt.figure(figsize=(8, 5))
plt.plot(WS2_Discharge_df['Date'], WS2_Discharge_df['Q'])
plt.title('WS2_Discharge_df')
plt.xlabel('Date')
plt.ylabel('Q')
plt.show()

# Plotting WS2_DSi_df
plt.figure(figsize=(8, 5))
plt.plot(WS2_DSi_df['Date'], WS2_DSi_df['value_mgL'])
plt.title('WS2_DSi_df')
plt.xlabel('Date')
plt.ylabel('value_mgL')
plt.show()

# %%
# Identify the frequency of observations for the Date column
print("evap_df:")
print(pd.infer_freq(pd.date_range(start=evap_df['Date'].min(), end=evap_df['Date'].max())))

print("\nGWS_tavg_df:")
print(pd.infer_freq(pd.date_range(start=GWS_tavg_df['Date'].min(), end=GWS_tavg_df['Date'].max())))

print("\nRain_f_ta_df:")
print(pd.infer_freq(pd.date_range(start=Rain_f_ta_df['Date'].min(), end=Rain_f_ta_df['Date'].max())))

print("\nSWE_tavg_df:")
print(pd.infer_freq(pd.date_range(start=SWE_tavg_df['Date'].min(), end=SWE_tavg_df['Date'].max())))

print("\nTair_f_tavg_df:")
print(pd.infer_freq(pd.date_range(start=Tair_f_tavg_df['Date'].min(), end=Tair_f_tavg_df['Date'].max())))

print("\nTWS_tavg_df:")
print(pd.infer_freq(pd.date_range(start=TWS_tavg_df['Date'].min(), end=TWS_tavg_df['Date'].max())))

print("\nWS2_Discharge_df:")
print(pd.infer_freq(pd.date_range(start=WS2_Discharge_df['Date'].min(), end=WS2_Discharge_df['Date'].max())))

print("\nWS2_DSi_df:")
print(pd.infer_freq(pd.date_range(start=WS2_DSi_df['Date'].min(), end=WS2_DSi_df['Date'].max())))
# Out:
# evap_df:
# D
#
# GWS_tavg_df:
# D
#
# Rain_f_ta_df:
# D
#
# SWE_tavg_df:
# D
#
# Tair_f_tavg_df:
# D
#
# TWS_tavg_df:
# D
#
# WS2_Discharge_df:
# D
#
# WS2_DSi_df:
# D

# %%
evap_df = evap_df.rename(columns={'HBR_ws2': 'evap'})
evap_df
# Out:
#            Date      evap
# 0    1965-01-01  0.000134
# 1    1965-01-02  0.000074
# 2    1965-01-03  0.000081
# 3    1965-01-04  0.000080
# 4    1965-01-05  0.000034
# ...         ...       ...
# 4811 1978-03-08  0.000019
# 4812 1978-03-09  0.000018
# 4813 1978-03-10  0.000015
# 4814 1978-03-11  0.000012
# 4815 1978-03-12  0.000020
#
# [4816 rows x 2 columns]

# %%
evap_df = evap_df.rename(columns={'HBR_ws2': 'evap'})
GWS_tavg_df = GWS_tavg_df.rename(columns={'HBR_ws2': 'GWS'})
Rain_f_ta_df = Rain_f_ta_df.rename(columns={'HBR_ws2': 'Rain_f_ta'})
SWE_tavg_df = SWE_tavg_df.rename(columns={'HBR_ws2': 'SWE'})
Tair_f_tavg_df = Tair_f_tavg_df.rename(columns={'HBR_ws2': 'Tair_f_tavg'})
TWS_tavg_df = TWS_tavg_df.rename(columns={'HBR_ws2': 'TWS'})

# %%
# Displaying the first few rows of each dataframe
print("evap_df:")
print(evap_df.head())

print("\nGWS_tavg_df:")
print(GWS_tavg_df.head())

print("\nRain_f_ta_df:")
print(Rain_f_ta_df.head())

print("\nSWE_tavg_df:")
print(SWE_tavg_df.head())

print("\nTair_f_tavg_df:")
print(Tair_f_tavg_df.head())

print("\nTWS_tavg_df:")
print(TWS_tavg_df.head())

print("\nWS2_Discharge_df:")
print(WS2_Discharge_df.head())

print("\nWS2_DSi_df:")
print(WS2_DSi_df.head())
# Out:
# evap_df:
#         Date      evap
# 0 1965-01-01  0.000134
# 1 1965-01-02  0.000074
# 2 1965-01-03  0.000081
# 3 1965-01-04  0.000080
# 4 1965-01-05  0.000034
#
# GWS_tavg_df:
#         Date          GWS
# 0 1965-01-01  1355.841064
# 1 1965-01-02  1355.867798
# 2 1965-01-03  1355.743408
# 3 1965-01-04  1355.505737
# 4 1965-01-05  1355.300537
#
# Rain_f_ta_df:
#         Date     Rain_f_ta
# 0 1965-01-01  4.758085e-07
# 1 1965-01-02  1.472223e-06
# 2 1965-01-03  2.042398e-05
# 3 1965-01-04  9.216375e-05
# 4 1965-01-05  2.777230e-05
#
# SWE_tavg_df:
#         Date        SWE
# 0 1965-01-01  32.474033
# 1 1965-01-02  22.969460
# 2 1965-01-03  18.499897
# 3 1965-01-04  17.172014
# 4 1965-01-05  16.777233
#
# Tair_f_tavg_df:
#         Date  Tair_f_tavg
# 0 1965-01-01   264.929535
# 1 1965-01-02   260.363312
# 2 1965-01-03   263.606293
# 3 1965-01-04   266.839752
# 4 1965-01-05   263.835114
#
# TWS_tavg_df:
#         Date          TWS
# 0 1965-01-01  1599.702271
# 1 1965-01-02  1590.059570
# ...

# %%
# Change the column names in the respective DataFrames
evap_df = evap_df.rename(columns={'evap': 'evap'})
GWS_tavg_df = GWS_tavg_df.rename(columns={'GWS': 'GWS'})
Rain_f_ta_df = Rain_f_ta_df.rename(columns={'Rain_f_ta': 'Rain_f_ta'})
SWE_tavg_df = SWE_tavg_df.rename(columns={'SWE': 'SWE'})
Tair_f_tavg_df = Tair_f_tavg_df.rename(columns={'Tair_f_tavg': 'Tair_f_tavg'})
TWS_tavg_df = TWS_tavg_df.rename(columns={'TWS': 'TWS'})

# Convert 'Date' column to datetime format
evap_df['Date'] = pd.to_datetime(evap_df['Date'])
GWS_tavg_df['Date'] = pd.to_datetime(GWS_tavg_df['Date'])
Rain_f_ta_df['Date'] = pd.to_datetime(Rain_f_ta_df['Date'])
SWE_tavg_df['Date'] = pd.to_datetime(SWE_tavg_df['Date'])
Tair_f_tavg_df['Date'] = pd.to_datetime(Tair_f_tavg_df['Date'])
TWS_tavg_df['Date'] = pd.to_datetime(TWS_tavg_df['Date'])
WS2_Discharge_df['Date'] = pd.to_datetime(WS2_Discharge_df['Date'])
WS2_DSi_df['Date'] = pd.to_datetime(WS2_DSi_df['Date'])

# Set 'Date' column as index
evap_df.set_index('Date', inplace=True)
GWS_tavg_df.set_index('Date', inplace=True)
Rain_f_ta_df.set_index('Date', inplace=True)
SWE_tavg_df.set_index('Date', inplace=True)
Tair_f_tavg_df.set_index('Date', inplace=True)
TWS_tavg_df.set_index('Date', inplace=True)
WS2_Discharge_df.set_index('Date', inplace=True)
WS2_DSi_df.set_index('Date', inplace=True)

# Merge all dataframes based on the 'Date' column
master_df = pd.concat([evap_df, GWS_tavg_df, Rain_f_ta_df, SWE_tavg_df, Tair_f_tavg_df, TWS_tavg_df, WS2_Discharge_df, WS2_DSi_df], axis=1)

# Count non-NaN values for each column
non_nan_count = master_df.count()

# Display the count of non-NaN values for each column
print(non_nan_count)

# Save master_df as master.csv
master_df.to_csv("master.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Change the column names in the respective DataFrames
evap_df = evap_df.rename(columns={'evap': 'evap'})
GWS_tavg_df = GWS_tavg_df.rename(columns={'GWS': 'GWS'})
Rain_f_ta_df = Rain_f_ta_df.rename(columns={'Rain_f_ta': 'Rain_f_ta'})
SWE_tavg_df = SWE_tavg_df.rename(columns={'SWE': 'SWE'})
Tair_f_tavg_df = Tair_f_tavg_df.rename(columns={'Tair_f_tavg': 'Tair_f_tavg'})
TWS_tavg_df = TWS_tavg_df.rename(columns={'TWS': 'TWS'})

# Set 'Date' column as index
evap_df.set_index('Date', inplace=True)
GWS_tavg_df.set_index('Date', inplace=True)
Rain_f_ta_df.set_index('Date', inplace=True)
SWE_tavg_df.set_index('Date', inplace=True)
Tair_f_tavg_df.set_index('Date', inplace=True)
TWS_tavg_df.set_index('Date', inplace=True)
WS2_Discharge_df.set_index('Date', inplace=True)
WS2_DSi_df.set_index('Date', inplace=True)

# Merge all dataframes based on the 'Date' column
master_df = pd.concat([evap_df, GWS_tavg_df, Rain_f_ta_df, SWE_tavg_df, Tair_f_tavg_df, TWS_tavg_df, WS2_Discharge_df, WS2_DSi_df], axis=1)

# Count non-NaN values for each column
non_nan_count = master_df.count()

# Display the count of non-NaN values for each column
print(non_nan_count)

# Save master_df as master.csv
master_df.to_csv("master.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28112\19060996.py in <module>
#       8
#       9 # Set 'Date' column as index
# ---> 10 evap_df.set_index('Date', inplace=True)
#      11 GWS_tavg_df.set_index('Date', inplace=True)
#      12 Rain_f_ta_df.set_index('Date', inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5501
#    5502         if missing:
# -> 5503             raise KeyError(f"None of {missing} are in the columns")
#    5504
#    5505         if inplace:
#
# ...

# %%
master_df = pd.concat([evap_df, GWS_tavg_df, Rain_f_ta_df, SWE_tavg_df, Tair_f_tavg_df, TWS_tavg_df, WS2_Discharge_df, WS2_DSi_df], axis=1)

# %%
master_df.shape
# Out:
# (4819, 8)

# %%
non_nan_count = master_df.count()

# Display the count of non-NaN values for each column
print(non_nan_count)

# Save master_df as master.csv
master_df.to_csv("master.csv")
# Out:
# evap           4816
# GWS            4816
# Rain_f_ta      4816
# SWE            4816
# Tair_f_tavg    4816
# TWS            4816
# Q              4748
# value_mgL       134
# dtype: int64

# %%
time_diff1 = WS2_DSi_df.index.to_series().diff().mean()

# Print the time difference
print(f"The frequency of observations for the column 'value_mgL' is approximately {time_diff1.days} days.")
# Out:
# The frequency of observations for the column 'value_mgL' is approximately 35 days.

# %%
# Count NaN values in master_df
nan_count = master_df.isna().sum()

# Display the count of NaN values for each column
print("NaN count in each column:")
print(nan_count)
# Out:
# NaN count in each column:
# evap              3
# GWS               3
# Rain_f_ta         3
# SWE               3
# Tair_f_tavg       3
# TWS               3
# Q                71
# value_mgL      4685
# dtype: int64

# %%
master_df.head(35)
# Out:
#                 evap          GWS     Rain_f_ta        SWE  Tair_f_tavg  \
# Date
# 1965-01-01  0.000134  1355.841064  4.758085e-07  32.474033   264.929535
# 1965-01-02  0.000074  1355.867798  1.472223e-06  22.969460   260.363312
# 1965-01-03  0.000081  1355.743408  2.042398e-05  18.499897   263.606293
# 1965-01-04  0.000080  1355.505737  9.216375e-05  17.172014   266.839752
# 1965-01-05  0.000034  1355.300537  2.777230e-05  16.777233   263.835114
# 1965-01-06  0.000060  1355.049561  0.000000e+00  14.420487   261.595673
# 1965-01-07  0.000027  1354.711060  2.952464e-07  11.106107   261.477997
# 1965-01-08  0.000020  1354.391235  0.000000e+00   9.500694   262.178680
# 1965-01-09  0.000030  1353.983521  0.000000e+00   7.655660   260.566895
# 1965-01-10  0.000012  1353.576172  0.000000e+00   6.508490   260.992981
# 1965-01-11  0.000017  1353.197021  0.000000e+00   5.842195   267.436676
# 1965-01-12  0.000024  1352.657104  0.000000e+00   4.666656   264.669220
# ...

# %%
master_df['Date'] = pd.to_datetime(master_df['Date'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
